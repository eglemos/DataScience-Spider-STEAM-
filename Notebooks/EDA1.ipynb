# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.options.display.float_format = '{:20,.2f}'.format

# %%
df = pd.read_csv('../CSV/games.csv', parse_dates=['release_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26960 entries, 0 to 26959
# Data columns (total 9 columns):
# url                26960 non-null object
# developer          26717 non-null object
# genre              26839 non-null object
# overall_Reviews    22270 non-null object
# price              26960 non-null object
# release_date       26960 non-null object
# score              1186 non-null float64
# title              26840 non-null object
# pricef             26960 non-null float64
# dtypes: float64(2), object(7)
# memory usage: 1.9+ MB

# %%
df.head(10)
# Out:
#                                                  url  \
# 0  http://store.steampowered.com/app/727960/Xagia...
# 1  http://store.steampowered.com/app/696770/KNOSS...
# 2  http://store.steampowered.com/app/684840/agech...
# 3  http://store.steampowered.com/app/677920/Acuca...
# 4  http://store.steampowered.com/app/671430/agech...
# 5  http://store.steampowered.com/app/680590/Minot...
# 6  http://store.steampowered.com/app/700360/Knigh...
# 7  http://store.steampowered.com/app/670750/0N_0W...
# 8  http://store.steampowered.com/app/659030/Black...
# 9  http://store.steampowered.com/app/682740/Data_...
#
#                                            developer      genre  \
# 0                                         NextHeaven     Casual
# 1                               Svarun Entertainment  Adventure
# 2                                        Gory Gaming     Action
# 3                                     Trifulca Force     Action
# ...

# %%
indie = pd.read_csv('../CSV/indie.csv')
indie.head(10)
# Out:
#                                                  url  \
# 0  http://store.steampowered.com/app/727960/Xagia...
# 1  http://store.steampowered.com/app/696770/KNOSS...
# 2  http://store.steampowered.com/app/684840/agech...
# 3  http://store.steampowered.com/app/677920/Acuca...
# 4  http://store.steampowered.com/app/671430/agech...
# 5  http://store.steampowered.com/app/680590/Minot...
# 6  http://store.steampowered.com/app/700360/Knigh...
# 7  http://store.steampowered.com/app/670750/0N_0W...
# 8  http://store.steampowered.com/app/659030/Black...
# 9  http://store.steampowered.com/app/682740/Data_...
#
#                                            developer      genre  \
# 0                                         NextHeaven     Casual
# 1                               Svarun Entertainment  Adventure
# 2                                        Gory Gaming     Action
# 3                                     Trifulca Force     Action
# ...
