# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.options.display.float_format = '{:20,.2f}'.format

# %%
indie = pd.read_csv('../CSV/indie.csv')
rpg = pd.read_csv('../CSV/rpg.csv')
strategy = pd.read_csv('../CSV/strategy.csv')

# %%
df = pd.concat([indie, rpg, strategy])

# %%
udf = df[~df.duplicated()]

# %%
del udf['...']
# Out:
#                                                     url  \
# 0     http://store.steampowered.com/agecheck/app/225...
# 1     http://store.steampowered.com/agecheck/app/225...
# 2     http://store.steampowered.com/app/502970/agech...
# 3     http://store.steampowered.com/app/225700/Falle...
# 4     http://store.steampowered.com/app/220121/C9_St...
# 5     http://store.steampowered.com/app/220120/Conti...
# 6     http://store.steampowered.com/agecheck/app/335...
# 7     http://store.steampowered.com/agecheck/app/335...
# 8     http://store.steampowered.com/app/220120/Conti...
# 9     http://store.steampowered.com/app/503430/N0EXI...
# 10    http://store.steampowered.com/app/708770/ARK_A...
# 11    http://store.steampowered.com/app/270741/Realm...
# 12    http://store.steampowered.com/app/365381/Battl...
# 13    http://store.steampowered.com/app/310591/Realm...
# 14    http://store.steampowered.com/app/310590/Realm...
# 15    http://store.steampowered.com/app/270744/Realm...
# ...

# %%
udf
# Out:
#                                                     url  \
# 0     http://store.steampowered.com/app/727960/Xagia...
# 1     http://store.steampowered.com/app/696770/KNOSS...
# 2     http://store.steampowered.com/app/684840/agech...
# 3     http://store.steampowered.com/app/677920/Acuca...
# 4     http://store.steampowered.com/app/671430/agech...
# 5     http://store.steampowered.com/app/680590/Minot...
# 6     http://store.steampowered.com/app/700360/Knigh...
# 7     http://store.steampowered.com/app/670750/0N_0W...
# 8     http://store.steampowered.com/app/659030/Black...
# 9     http://store.steampowered.com/app/682740/Data_...
# 10    http://store.steampowered.com/app/678680/agech...
# 11    http://store.steampowered.com/app/682670/__The...
# 12    http://store.steampowered.com/app/674930/Boyfr...
# 13    http://store.steampowered.com/app/680750/Desti...
# 14    http://store.steampowered.com/app/679420/RoVR/...
# 15    http://store.steampowered.com/app/669740/Tower...
# ...

# %%
udf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26960 entries, 0 to 7955
# Data columns (total 10 columns):
# url                26960 non-null object
# developer          26717 non-null object
# genre              26839 non-null object
# overall_Reviews    22270 non-null object
# price              26960 non-null object
# release_date       26670 non-null object
# score              1186 non-null float64
# title              26840 non-null object
# url.1              26960 non-null object
# ...                26960 non-null object
# dtypes: float64(1), object(9)
# memory usage: 2.3+ MB

# %%
del udf['url.1']

# %%
udf.genre.unique()
# Out:
# array(['Casual', 'Adventure', 'Action', 'Indie', 'Animation', 'Free',
#        'Racing', 'Strategy', 'Simulation', 'Early', 'Audio', 'Verb', 'RPG',
#        'Video', 'Catbox', 'StudioBento', 'Sports', 'Design', 'Steve',
#        'Five', 'Devolver', 'Bury', 'Performance', 'Konec', 'Vile',
#        'Alienware', 'Coasting', 'Grandview', 'PDP', 'Historia', 'Nine',
#        'Okay', '2', 'Lionsgate', 'Common', 'Flame', 'Ale\xc5\xa1', 'Spiez',
#        'Education', 'Utilities', 'Assemblage', 'Imagos', nan, 'Massively',
#        'Degica', 'BANDAI', 'SEGA', 'Heroic', 'Shiny', 'Web', 'Ominous',
#        'Valve'], dtype=object)

# %%
def parse_price(x):
    try:
        return float(x)
    except:
        return 0

# %%
udf = udf.copy()
udf['pricef'] = udf.price.apply(parse_price)
udf['pricef'].head()
# Out:
# 0                   0.00
# 1                   0.00
# 2                  28.99
# 3                   0.00
# 4                  44.99
# Name: pricef, dtype: float64

# %%
udf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26960 entries, 0 to 7955
# Data columns (total 10 columns):
# url                26960 non-null object
# developer          26717 non-null object
# genre              26839 non-null object
# overall_Reviews    22270 non-null object
# price              26960 non-null object
# release_date       26670 non-null object
# score              1186 non-null float64
# title              26840 non-null object
# ...                26960 non-null object
# pricef             26960 non-null float64
# dtypes: float64(2), object(8)
# memory usage: 2.3+ MB

# %%
del udf['...']

# %%
udf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26960 entries, 0 to 7955
# Data columns (total 9 columns):
# url                26960 non-null object
# developer          26717 non-null object
# genre              26839 non-null object
# overall_Reviews    22270 non-null object
# price              26960 non-null object
# release_date       26670 non-null object
# score              1186 non-null float64
# title              26840 non-null object
# pricef             26960 non-null float64
# dtypes: float64(2), object(7)
# memory usage: 2.1+ MB

# %%
udf.overall_Reviews.unique()
# Out:
# array([nan, 'No user reviews', 'Mostly Negative', 'Mostly Positive',
#        'Mixed', '8 user reviews', '3 user reviews', '4 user reviews',
#        '9 user reviews', 'Very Negative', '2 user reviews', 'Negative',
#        '6 user reviews', '5 user reviews', '7 user reviews',
#        '1 user reviews', 'Very Positive', 'Overwhelmingly Positive',
#        'Positive', 'Overwhelmingly Negative'], dtype=object)

# %%
udf.to_csv('../CSV/games.csv', index=False)
